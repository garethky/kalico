# %% [markdown]
# # PA Calibration Viewer
#
# Loads a `.jsonl` file produced by `LOAD_CELL_PA_SWEEP_CAPTURE` and plots the force/time trace with junction markers for each run.

# %%
from pathlib import Path

JSONL_PATH = Path("../pa_calibrate_20.jsonl")

# %%
import json

import matplotlib.pyplot as plt
import numpy as np

records = []
with JSONL_PATH.expanduser().open("r", encoding="utf-8") as f:
    for line in f:
        line = line.strip()
        if line:
            records.append(json.loads(line))

for i, rec in enumerate(records):
    time = np.asarray(rec["time"], dtype=float)
    force = np.asarray(rec["force"], dtype=float)
    junctions = rec.get("junctions", [])

    fig, ax = plt.subplots(figsize=(14, 5))
    ax.plot(time, force, linewidth=0.8, alpha=0.9)

    _, ymax = ax.get_ylim()
    for junc in junctions:
        t_accel = junc["accel_start"]
        t_decel = junc["decel_start"]
        ax.axvline(t_accel, color="0.25", linestyle="-", linewidth=0.8, alpha=0.8)
        ax.axvline(t_decel, color="0.55", linestyle="--", linewidth=0.7, alpha=0.7)
        ax.text(
            t_accel, ymax, f"J{junc['index']}",
            rotation=90, va="top", ha="right", fontsize=7, color="0.25",
        )

    speed = rec.get("speed", "?")
    accel = rec.get("accel", "?")
    flow = rec.get("flow_rate", "?")
    ax.set_title(f"Run {i}: speed={speed} accel={accel} flow={flow}")
    ax.set_xlabel("Time (s)")
    ax.set_ylabel("Force (g)")
    ax.grid(True, alpha=0.3)
    fig.tight_layout()
    plt.show()
